# %%
#import numpy as np
#import pandas as pd

#dataset=pd.read_csv('/content/drive/MyDrive/ibm/Churn_Modelling.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns

df=pd.read_csv('/content/drive/MyDrive/ibm/Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# Univariate **Analysis** ***bold text***

# %%
sns.countplot(x='IsActiveMember',data=df)

# %%
sns.histplot(x="CreditScore",data=df,color='red')

# %%
sns.distplot(df["Balance"],color='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***Bi - Variate Analysis***

# %%
sns.barplot(df['Age'],df['Balance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(df['Age'],df['Tenure'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(data=df, kind="bar", x="IsActiveMember", y="CustomerId")

# %%
sns.catplot(data=df, kind="violin", x="Gender", y="Tenure", split=True)

# %%
sns.pairplot(df,hue='Gender')

# %% [markdown]
# **Describe the dataset**

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# **Handle the Missing values**

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# **Find the outliers and replace the outliers**

# %%
Quan1 = df['Age'].quantile(0.25)
Quan3 = df['Age'].quantile(0.75)
IQR = Quan3 - Quan1
lowerbound = Quan1 - 1.5 * IQR
upperbound = Quan3 + 1.5 * IQR
Quan1,Quan3,IQR,lowerbound,upperbound
df[(df['Age'] < lowerbound) | (df['Age'] > upperbound)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 58           59    15623944        T'ien          511     Spain  Female   66
# 85           86    15805254      Ndukaku          652     Spain  Female   75
# 104         105    15804919     Dunbabin          670     Spain  Female   65
# 158         159    15589975      Maclean          646    France  Female   73
# 181         182    15789669         Hsia          510    France    Male   65
# ...         ...         ...          ...          ...       ...     ...  ...
# 9753       9754    15705174    Chiedozie          656   Germany    Male   68
# 9765       9766    15777067       Thomas          445    France    Male   64
# 9832       9833    15814690  Chukwujekwu          595   Germany  Female   64
# 9894       9895    15704795        Vagin          521    France  Female   77
# 9936       9937    15653037        Parks          609    France    Male   77
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 58         4       0.00              1          1               0
# 85        10       0.00              2          1               1
# 104        1       0.00              1          1               1
# 158        6   97259.25              1          0               1
# 181        2       0.00              2          1               1
# ...      ...        ...            ...        ...             ...
# 9753       7  153545.11              1          1               1
# 9765       2  136770.67              1          0               1
# 9832       2  105736.32              1          1               1
# 9894       6       0.00              2          1               1
# 9936       1       0.00              1          0               1
#
#       EstimatedSalary  Exited
# 58            1643.11       1
# 85          114675.75       0
# 104         177655.68       1
# 158         104719.66       0
# 181          48071.61       0
# ...               ...     ...
# 9753        186574.68       0
# 9765         43678.06       0
# 9832         89935.73       1
# 9894         49054.10       0
# 9936         18708.76       0
#
# [359 rows x 14 columns]

# %%
df = df[(df['Age'] > lowerbound) & (df['Age'] < upperbound)]
sns.boxplot(df['Age'], color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['CreditScore'],color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Split the data into dependent and independent variables.**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Geography'] = le.fit_transform(df['Geography'])
df['Gender'] = le.fit_transform(df['Gender'])
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619          0       0   42
# 1          2    15647311      Hill          608          2       0   41
# 2          3    15619304      Onio          502          0       0   42
# 3          4    15701354      Boni          699          0       0   39
# 4          5    15737888  Mitchell          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
z = df.iloc[:,3:13]
z.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
exited = df['Exited']
exited.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# ** Scale the independent variables**

# %%
m_columns = x.select_dtypes(include=np.number).columns.tolist()
m_columns
# Out:
# ['CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x[m_columns] = scaler.fit_transform(x[m_columns])
x.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0    -0.323704  -0.901758 -1.096745  0.502054 -1.043472 -1.226428
# 1    -0.437511   1.516632 -1.096745  0.386361 -1.389684  0.116241
# 2    -1.534189  -0.901758 -1.096745  0.502054  1.033796  1.331465
# 3     0.503977  -0.901758 -1.096745  0.154977 -1.389684 -1.226428
# 4     2.066226   1.516632 -1.096745  0.617746 -1.043472  0.784355
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0      -0.913071   0.645612        0.995733         0.019976
# 1      -0.913071  -1.548919        0.995733         0.214656
# 2       2.526503   0.645612       -1.004285         0.238814
# 3       0.806716  -1.548919       -1.004285        -0.110850
# 4      -0.913071   0.645612        0.995733        -0.367251

# %% [markdown]
# ** Split the data into training and testing**

# %%
x.shape
# Out:
# (9589, 10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,z,test_size=0.2,random_state=0)
x_train.head()
# Out:
#       CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 6313    -0.778929  -0.901758  0.911789 -1.233333 -0.697261  1.005296
# 664      0.110828  -0.901758 -1.096745  0.386361 -1.389684 -1.226428
# 3991    -1.596265   0.307437 -1.096745  2.468826  0.687585  0.242360
# 8237    -0.013324  -0.901758  0.911789  0.154977 -0.697261  0.585467
# 8348    -0.085746   0.307437 -1.096745 -0.192101 -1.043472  0.768097
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 6313      -0.913071   0.645612       -1.004285        -0.006197
# 664        0.806716  -1.548919        0.995733         0.540896
# 3991       0.806716   0.645612       -1.004285         1.094663
# 8237      -0.913071   0.645612        0.995733        -0.693330
# 8348       2.526503   0.645612        0.995733        -0.735610

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((7671, 10), (7671, 10), (1918, 10), (1918, 10))
